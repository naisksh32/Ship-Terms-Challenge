# %%
import pandas as pd

# %%
file_path = r'C:\ITStudy\101_TeamProject\Ship-Word-Challenge\성현\Code\make_test_set\eng_word_fixed.csv'
df = pd.read_csv(file_path, sep='|', encoding='utf-8')
df
# Out:
#                                    영단어                     한국단어  \
# 0           (Bulbous)Bow Warning Light                 구상선수 주의등
# 1                  0.50% Sulphur limit        연료유 0.5% 황 함유량 규제
# 2     2nd GENERATION INTACT STABLILITY              2세대 비손상 복원성
# 3                    2010 HNS Protocol  2010년 위험 유해물질의 해상운송에 따른
# 4               2010 Manila Amendments              2010 마닐라 개정
# ...                                ...                      ...
# 8123                standard Deviation                     표준편차
# 8124                    steam Radiator                    증기방열기
# 8125                steerage Passenger                     보통선객
# 8126                working Conditions              작업 여건(作業與件)
# 8127   ①Cross Section ②Transverse Plan                      횡단면
#
#                                                      설명
# 0               구상선수가 있음을 알리기 위하여 켜는 선수등으로 적색 또는 청색이 있음
# 1     0.50% Sulphur limit under MARPOL Annex VI, 선박에...
# ...

# %%
df_c = df.drop(columns=['설명'])
df_c
# Out:
#                                    영단어                     한국단어
# 0           (Bulbous)Bow Warning Light                 구상선수 주의등
# 1                  0.50% Sulphur limit        연료유 0.5% 황 함유량 규제
# 2     2nd GENERATION INTACT STABLILITY              2세대 비손상 복원성
# 3                    2010 HNS Protocol  2010년 위험 유해물질의 해상운송에 따른
# 4               2010 Manila Amendments              2010 마닐라 개정
# ...                                ...                      ...
# 8123                standard Deviation                     표준편차
# 8124                    steam Radiator                    증기방열기
# 8125                steerage Passenger                     보통선객
# 8126                working Conditions              작업 여건(作業與件)
# 8127   ①Cross Section ②Transverse Plan                      횡단면
#
# [8128 rows x 2 columns]

# %%
df_c.to_csv(r'C:\ITStudy\101_TeamProject\Ship-Word-Challenge\성현\Data\only_eng_kor_word.csv', index=False)
